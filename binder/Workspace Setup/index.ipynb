# %% [markdown]
# ## Setup

# %%
pip install labstep

# %%
import labstep

user = labstep.authenticate(username='YOUR_USERNAME',
                            apikey='YOUR_API_KEY')

# %% [markdown]
# ## Start coding
#
# ### Create a new workspace and set to that workspace

# %%
workspace = user.newWorkspace(name='Aspirin Project')
user.setWorkspace(workspace.id)

# %% [markdown]
# ![workspace_setup_aspirin_project.png](attachment:workspace_setup_aspirin_project.png)

# %% [markdown]
# ### Create an experiment

# %%
my_experiment = user.newExperiment(name='Synthesis of Aspirin',
                                   description='Aspirin is a drug...')

# %% [markdown]
# ### Create a protocol

# %%
my_protocol = user.newProtocol('Aspirin Synthesis')

# %% [markdown]
# ![workspace_setup_new_entities.png](attachment:workspace_setup_new_entities.png)

# %% [markdown]
# ### Add resources

# %%
salicylic_acid = user.newResource('Salicylic Acid')
salicylic_acid.addComment('Here is the chemical structure',
                          './salicylic_acid.png')
salicylic_acid.addMetadata(fieldName='Formula', value='C7H6O3')
salicylic_acid.addMetadata(fieldName='Hazards', value='Corrosive, irritant')
# ... etc.

# %% [markdown]
# ![workspace_setup_comment.png](attachment:workspace_setup_comment.png)
#
# ![workspace_setup_salicylic_acid.png](attachment:workspace_setup_salicylic_acid.png)

# %% [markdown]
# ### Create a resource category

# %%
chemicalCategory = user.newResourceCategory('Chemical')
chemicalCategory.addMetadata(fieldName='Molar mass')
chemicalCategory.addMetadata(fieldName='Density')
chemicalCategory.addMetadata(fieldName='Melting point')

# %% [markdown]
# ![workspace_setup_resource_cat.png](attachment:workspace_setup_resource_cat.png)

# %% [markdown]
# ### Upload any file

# %%
user.newFile('./salicylic_acid.png')

# %% [markdown]
# ![workspace_setup_newFile.png](attachment:workspace_setup_newFile.png)
